# %% [markdown]
# # Sunshine Heavy Industries Constraint Solver
#
# Currently only solves for basic numerical constraints + fuel & heatsink adjacency
#
# todo: armor requirements, cloaking area constraints, energy area constraints.

# %%
from json import loads
import numpy as np
import pandas as pd
from pyomo.environ import *

costs = None
with open("costs.json") as f:
    costs = list(loads(f.read()).items())

print(f"Parts in DB: {len(costs)}")
# Out:
# Parts in DB: 108

# %%
def prop_vector(prop_name, default=0):
    return np.array([data.get(prop_name, default) for _, data in costs])

names = [n for n, _ in costs]
hitboxes = [np.array(data.get('hitbox', np.ones([data.get('width'),data.get('height')]))) for _, data in costs]
area = np.array([np.count_nonzero(hb) for hb in hitboxes])

borders = np.array([[not x in ob for x in range(4)] for ob in prop_vector('mustBeUnobstructed', [])])

perimeter = \
    prop_vector('height') * borders[:,0] + \
    prop_vector('width') * borders[:, 1] + \
    prop_vector('height') * borders[:, 2] + \
    prop_vector('width') * borders[:, 3]

data = pd.DataFrame({
    'part': names,
    'cost': area * prop_vector('cost'),
    'energy': area * prop_vector('energy'),
    'fuel': area * prop_vector('fuel'),
    'firepower': area * prop_vector('firepower'),
    'passenger': area * prop_vector('quarters'),
    'command': area * prop_vector('command'),
    'cargo': area * prop_vector('cargo'),
    'fuelAdjacency': prop_vector('pump') * perimeter - prop_vector('mustTouchFuelPump'),
    'sinkAdjacency': prop_vector('heatsink') * perimeter - prop_vector('heat'),
})

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

data.set_index('part', inplace=True)
data
# Out:
#                        cost  energy  fuel  firepower  passenger  command  \
# part
# antenna_1x2           100.0     0.0     0          0          0        0
# antenna_1x4           400.0     0.0     0          0          0        0
# antenna_1x5           300.0     0.0     0          0          0        0
# bunk_1x1               20.0     0.0     0          0          1        0
# bunk_2x1               40.0     0.0     0          0          2        0
# bunk_4x1               80.0     0.0     0          0          4        0
# bunk_4x2              160.0     0.0     0          0          8        0
# bunk_norad_4x2        320.0     0.0     0          0          8        0
# cab_2x2               400.0     0.0     0          0          4        4
# cannon_2x1             70.0    -2.0     0          2          0        0
# cannon_2x3            240.0    -6.0     0          6          0        0
# cannon_4x3            540.0   -12.0     0         12          0        0
# cannon_5x1            200.0    -5.0     0          5          0        0
# cargo_1x1              20.0     0.0     0          0          0        0
# cargo_2x1              40.0     0.0     0          0          0        0
# cargo_2x2              80.0     0.0     0          0          0        0
# cargo_5x2             200.0     0.0     0          0          0        0
# cargo_rad_3x2         120.0     0.0     0          0          0        0
# claw_3x3              450.0   -45.0     0          0          0        0
# cloak_1x1             500.0   -40.0     0          0          0        0
# cloak_3x3            1080.0  -270.0     0          0          0        0
# cockpit_1x1           100.0     0.0     0          0          0        1
# cockpit_1x2           180.0     0.0     0          0          0        2
# cockpit_1x4           320.0     0.0     0          0          0        4
# cockpit_2x2           400.0     0.0     0          0          0        4
# cockpit_2x4           800.0     0.0     0          0          0        8
# cone_1x2               20.0     0.0     0          0          0        0
# cpu_2x2               800.0   -20.0     0          0          0        0
# dish_2x2              720.0     0.0     0          0          0        0
# drill_3x3             360.0   -45.0     0          9          0        0
# engine_3x1             60.0     0.0     0          0          0        0
# engine_3x2            180.0     0.0     0          0          0        0
# engine_4x2            240.0     0.0     0          0          0        0
# engine_5x1            125.0     0.0     0          0          0        0
# engine_6x3            630.0     0.0     0          0          0        0
# engine_7x4            960.0     0.0     0          0          0        0
# engine_rainbow_4x3    360.0    -6.0     0          0          0        0
# enginedirty_4x2       360.0     0.0     0          0          0        0
# enginegarbo_8x5      1280.0     0.0     0          0          0        0
# enginegold_4x2        480.0     0.0     0          0          0        0
# engineion_4x2         240.0    -8.0     0          0          0        0
# fin_1x2                40.0     0.0     0          0          0        0
# fin_2x2                80.0     0.0     0          0          0        0
# fin_3x3               140.0     0.0     0          0          0        0
# fin_4x4               260.0     0.0     0          0          0        0
# fin_cannon_3x3        540.0    -9.0     0          9          0        0
# flier_1x1              10.0     0.0     0          0          0        0
# ftlcore_2x3          1200.0  -120.0     0          0          0        0
# generator_1x1         200.0    10.0     0          0          0        0
# generator_2x2         600.0    40.0     0          0          0        0
# gpu_3x1               600.0   -15.0     0          0          0        0
# greenhouse_5x3        375.0   -15.0     0          0          0        0
# heat_pipe_2x3         420.0     0.0     0          0          0        0
# heat_vent_1x1          70.0     0.0     0          0          0        0
# heatsink_1x2          100.0     0.0     0          0          0        0
# heatsink_1x3          135.0     0.0     0          0          0        0
# horn_2x1              100.0     0.0     0          0          0        0
# hull_round_2x2         20.0     0.0     0          0          0        0
# hull_round_4x4         50.0     0.0     0          0          0        0
# intake_3x2            600.0    30.0     0          0          0        0
# lab_2x3              1200.0    -6.0     0          0          0        0
# panel_10x1            100.0     0.0     0          0          0        0
# panel_1x1              10.0     0.0     0          0          0        0
# panel_2x1              20.0     0.0     0          0          0        0
# panel_3x1              30.0     0.0     0          0          0        0
# panel_4x1              40.0     0.0     0          0          0        0
# panel_concave_2x2      20.0     0.0     0          0          0        0
# panel_concave_4x4      50.0     0.0     0          0          0        0
# panel_corner2_1x1      10.0     0.0     0          0          0        0
# panel_corner_1x1       10.0     0.0     0          0          0        0
# panel_corner_2x1       20.0     0.0     0          0          0        0
# panel_corner_2x2       20.0     0.0     0          0          0        0
# panel_curve_2x2        20.0     0.0     0          0          0        0
# propeller_2x2          80.0     0.0     0          0          0        0
# pump_1x1              200.0     0.0     0          0          0        0
# pump_1x2              300.0     0.0     0          0          0        0
# pumpcast_2x2          700.0    -4.0     0          0          0        0
# radar_1x1             100.0    -1.0     0          0          0        0
# radar_1x2             200.0    -2.0     0          0          0        0
# radar_2x3             600.0    -6.0     0          0          0        0
# radar_longrange_2x3  1200.0   -12.0     0          0          0        0
# ram_2x1               400.0   -10.0     0          0          0        0
# reactor_3x2          1800.0   300.0     0          0          0        0
# scaffold_1x1            5.0     0.0     0          0          0        0
# scaffold_1x2           10.0     0.0     0          0          0        0
# scaffold_1x20         100.0     0.0     0          0          0        0
# scaffold_1x4           20.0     0.0     0          0          0        0
# scrap_1x1              20.0     0.0     0          0          0        0
# scrap_1x2              40.0     0.0     0          0          0        0
# scrap_2x2              80.0     0.0     0          0          0        0
# scrap_2x3             120.0     0.0     0          0          0        0
# solar_panel_3x1       375.0    18.0     0          0          0        0
# speaker_1x1            30.0    -2.0     0          0          0        0
# stage_6x3             540.0     0.0     0          0          0        0
# stasis_pod_2x1        200.0   -10.0     0          0          0        0
# tank_1x1               30.0     0.0     1          0          0        0
# tank_2x1               60.0     0.0     2          0          0        0
# tank_2x2              120.0     0.0     4          0          0        0
# tank_3x1               90.0     0.0     3          0          0        0
# tank_4x2              240.0     0.0     8          0          0        0
# tank_6x3              540.0     0.0    18          0          0        0
# tank_cylinder_3x4     420.0     0.0    12          0          0        0
# tank_hull_4x1         140.0     0.0     4          0          0        0
# tank_pod_3x3          315.0     0.0     9          0          0        0
# tractorbeam_2x3       120.0    -8.0     0          0          0        0
# turbine_2x2           900.0    40.0     0          0          0        0
# turret_5x2            400.0   -10.0     0         10          0        0
# turret_6x3            810.0   -18.0     0         18          0        0
#
#                      cargo  fuelAdjacency  sinkAdjacency
# part
# antenna_1x2              0              0              0
# antenna_1x4              0              0              0
# antenna_1x5              0              0              0
# bunk_1x1                 0              0              0
# bunk_2x1                 0              0              0
# bunk_4x1                 0              0              0
# bunk_4x2                 0              0              0
# bunk_norad_4x2           0              0              0
# cab_2x2                  0              0              0
# cannon_2x1               0              0             -1
# cannon_2x3               0              0             -1
# cannon_4x3               0              0             -1
# cannon_5x1               0              0             -1
# cargo_1x1                1              0              0
# cargo_2x1                2              0              0
# cargo_2x2                4              0              0
# cargo_5x2               10              0              0
# cargo_rad_3x2            6              0              0
# claw_3x3                 0              0              0
# cloak_1x1                0              0              0
# cloak_3x3                0              0             -1
# cockpit_1x1              0              0              0
# cockpit_1x2              0              0              0
# cockpit_1x4              0              0              0
# cockpit_2x2              0              0              0
# cockpit_2x4              0              0              0
# cone_1x2                 0              0              0
# cpu_2x2                  0              0             -1
# dish_2x2                 0              0             -1
# drill_3x3                0              0             -1
# engine_3x1               0             -1             -1
# engine_3x2               0             -1             -1
# engine_4x2               0             -1             -1
# engine_5x1               0             -1             -1
# engine_6x3               0             -1             -1
# engine_7x4               0             -1             -1
# engine_rainbow_4x3       0             -1             -1
# enginedirty_4x2          0             -1             -1
# enginegarbo_8x5          0              0             -1
# enginegold_4x2           0             -1             -1
# engineion_4x2            0              0              0
# fin_1x2                  0              0              0
# fin_2x2                  0              0              0
# fin_3x3                  0              0              0
# fin_4x4                  0              0              0
# fin_cannon_3x3           0              0             -1
# flier_1x1                0              0              0
# ftlcore_2x3              0              0             -1
# generator_1x1            0              0             -1
# generator_2x2            0              0             -1
# gpu_3x1                  0              0             -1
# greenhouse_5x3           0              0              0
# heat_pipe_2x3            0              0              0
# heat_vent_1x1            0              0              3
# heatsink_1x2             0              0              6
# heatsink_1x3             0              0              8
# horn_2x1                 0              0              0
# hull_round_2x2           0              0              0
# hull_round_4x4           0              0              0
# intake_3x2               0              0              8
# lab_2x3                  0              0              0
# panel_10x1               0              0              0
# panel_1x1                0              0              0
# panel_2x1                0              0              0
# panel_3x1                0              0              0
# panel_4x1                0              0              0
# panel_concave_2x2        0              0              0
# panel_concave_4x4        0              0              0
# panel_corner2_1x1        0              0              0
# panel_corner_1x1         0              0              0
# panel_corner_2x1         0              0              0
# panel_corner_2x2         0              0              0
# panel_curve_2x2          0              0              0
# propeller_2x2            0              0              0
# pump_1x1                 0              4              0
# pump_1x2                 0              6              0
# pumpcast_2x2             0              0              0
# radar_1x1                0              0             -1
# radar_1x2                0              0             -1
# radar_2x3                0              0             -1
# radar_longrange_2x3      0              0             -1
# ram_2x1                  0              0              0
# reactor_3x2              0              0             -1
# scaffold_1x1             0              0              0
# scaffold_1x2             0              0              0
# scaffold_1x20            0              0              0
# scaffold_1x4             0              0              0
# scrap_1x1                0              0              0
# scrap_1x2                0              0              0
# scrap_2x2                0              0              0
# scrap_2x3                0              0              0
# solar_panel_3x1          0              0              0
# speaker_1x1              0              0              0
# stage_6x3                0              0              0
# stasis_pod_2x1           0              0             -1
# tank_1x1                 0             -1              0
# tank_2x1                 0             -1              0
# tank_2x2                 0             -1              0
# tank_3x1                 0             -1              0
# tank_4x2                 0             -1              0
# tank_6x3                 0             -1              0
# tank_cylinder_3x4        0             -1              0
# tank_hull_4x1            0             -1              0
# tank_pod_3x3             0             -1              0
# tractorbeam_2x3          0              0             -1
# turbine_2x2              0              0              8
# turret_5x2               0              0             -1
# turret_6x3               0              0             -1

# %%
model = ConcreteModel()
model.x = Var(names, domain=NonNegativeIntegers)
model.total_cost = Objective(
    expr = sum(data.loc[i].cost *model.x[i] for i in names),
    sense = minimize
)
model.fuel = Constraint(
    expr = sum(data.loc[i].fuel * model.x[i] for i in names) >= 12
)
model.energy = Constraint(
    expr = sum(data.loc[i].energy * model.x[i] for i in names) >= 10
)
model.firepower = Constraint(
    expr = sum(data.loc[i].firepower * model.x[i] for i in names) >= 53
)
model.passenger = Constraint(
    expr = sum(data.loc[i].passenger * model.x[i] for i in names) >= 10
)
model.command = Constraint(
    expr = sum(data.loc[i].command * model.x[i] for i in names) >= 10
)
model.cargo = Constraint(
    expr = sum(data.loc[i].cargo * model.x[i] for i in names) >= 10
)
model.fuelAdjacency = Constraint(
    expr = sum(data.loc[i].fuelAdjacency * model.x[i] for i in names) >= 0
)
model.sinkAdjacency = Constraint(
    expr = sum(data.loc[i].sinkAdjacency * model.x[i] for i in names) >= 0
)

solver=SolverFactory('glpk', executable="/usr/local/bin/glpsol")
results = solver.solve(model)
print(results)
model.display()


res = []
for i in model.x:
    if(model.x[i].value > 0):
        res.append([str(model.x[i])[2:-1], int(model.x[i].value)])
        
df = pd.DataFrame(res, columns=['Part','Qty'])
df.style.hide_index()
# Out:
# Problem:
# - Name: unknown
#   Lower bound: 5090.0
#   Upper bound: 5090.0
#   Number of objectives: 1
#   Number of constraints: 9
#   Number of variables: 109
#   Number of nonzeros: 125
#   Sense: minimize
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 143
#       Number of created subproblems: 143
#   Error rc: 0
#   Time: 0.014417886734008789
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Model unknown
#
#   Variables:
#     x : Size=108, Index=x_index
#         Key                 : Lower : Value : Upper : Fixed : Stale : Domain
#                 antenna_1x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                 antenna_1x4 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                 antenna_1x5 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    bunk_1x1 :     0 :  10.0 :  None : False : False : NonNegativeIntegers
#                    bunk_2x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    bunk_4x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    bunk_4x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#              bunk_norad_4x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                     cab_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  cannon_2x1 :     0 :   1.0 :  None : False : False : NonNegativeIntegers
#                  cannon_2x3 :     0 :   1.0 :  None : False : False : NonNegativeIntegers
#                  cannon_4x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  cannon_5x1 :     0 :   1.0 :  None : False : False : NonNegativeIntegers
#                   cargo_1x1 :     0 :  10.0 :  None : False : False : NonNegativeIntegers
#                   cargo_2x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   cargo_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   cargo_5x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#               cargo_rad_3x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    claw_3x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   cloak_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   cloak_3x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                 cockpit_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                 cockpit_1x2 :     0 :   1.0 :  None : False : False : NonNegativeIntegers
#                 cockpit_1x4 :     0 :   2.0 :  None : False : False : NonNegativeIntegers
#                 cockpit_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                 cockpit_2x4 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    cone_1x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                     cpu_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    dish_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   drill_3x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  engine_3x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  engine_3x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  engine_4x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  engine_5x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  engine_6x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  engine_7x4 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#          engine_rainbow_4x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#             enginedirty_4x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#             enginegarbo_8x5 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#              enginegold_4x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#               engineion_4x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                     fin_1x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                     fin_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                     fin_3x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                     fin_4x4 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#              fin_cannon_3x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   flier_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                 ftlcore_2x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#               generator_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#               generator_2x2 :     0 :   1.0 :  None : False : False : NonNegativeIntegers
#                     gpu_3x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#              greenhouse_5x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#               heat_pipe_2x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#               heat_vent_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                heatsink_1x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                heatsink_1x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    horn_2x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#              hull_round_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#              hull_round_4x4 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  intake_3x2 :     0 :   1.0 :  None : False : False : NonNegativeIntegers
#                     lab_2x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  panel_10x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   panel_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   panel_2x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   panel_3x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   panel_4x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#           panel_concave_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#           panel_concave_4x4 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#           panel_corner2_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#            panel_corner_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#            panel_corner_2x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#            panel_corner_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#             panel_curve_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#               propeller_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    pump_1x1 :     0 :   1.0 :  None : False : False : NonNegativeIntegers
#                    pump_1x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                pumpcast_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   radar_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   radar_1x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   radar_2x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#         radar_longrange_2x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                     ram_2x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                 reactor_3x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                scaffold_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                scaffold_1x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#               scaffold_1x20 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                scaffold_1x4 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   scrap_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   scrap_1x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   scrap_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   scrap_2x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#             solar_panel_3x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                 speaker_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   stage_6x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#              stasis_pod_2x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    tank_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    tank_2x1 :     0 :   2.0 :  None : False : False : NonNegativeIntegers
#                    tank_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    tank_3x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    tank_4x2 :     0 :   1.0 :  None : False : False : NonNegativeIntegers
#                    tank_6x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#           tank_cylinder_3x4 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#               tank_hull_4x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                tank_pod_3x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#             tractorbeam_2x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                 turbine_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  turret_5x2 :     0 :   4.0 :  None : False : False : NonNegativeIntegers
#                  turret_6x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#
#   Objectives:
#     total_cost : Size=1, Index=None, Active=True
#         Key  : Active : Value
#         None :   True : 5090.0
#
#   Constraints:
#     fuel : Size=1
#         Key  : Lower : Body : Upper
#         None :  12.0 : 12.0 :  None
#     energy : Size=1
#         Key  : Lower : Body : Upper
#         None :  10.0 : 17.0 :  None
#     firepower : Size=1
#         Key  : Lower : Body : Upper
#         None :  53.0 : 53.0 :  None
#     passenger : Size=1
#         Key  : Lower : Body : Upper
#         None :  10.0 : 10.0 :  None
#     command : Size=1
#         Key  : Lower : Body : Upper
#         None :  10.0 : 10.0 :  None
#     cargo : Size=1
#         Key  : Lower : Body : Upper
#         None :  10.0 : 10.0 :  None
#     fuelAdjacency : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  1.0 :  None
#     sinkAdjacency : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :  None
# <style  type="text/css" >
# </style><table id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122" ><thead>    <tr>        <th class="col_heading level0 col0" >Part</th>        <th class="col_heading level0 col1" >Qty</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row0_col0" class="data row0 col0" >bunk_1x1</td>
#                         <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row0_col1" class="data row0 col1" >10</td>
#             </tr>
#             <tr>
#                                 <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row1_col0" class="data row1 col0" >cannon_2x1</td>
#                         <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row1_col1" class="data row1 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row2_col0" class="data row2 col0" >cannon_2x3</td>
#                         <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row2_col1" class="data row2 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row3_col0" class="data row3 col0" >cannon_5x1</td>
#                         <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row3_col1" class="data row3 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row4_col0" class="data row4 col0" >cargo_1x1</td>
#                         <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row4_col1" class="data row4 col1" >10</td>
#             </tr>
#             <tr>
#                                 <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row5_col0" class="data row5 col0" >cockpit_1x2</td>
#                         <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row5_col1" class="data row5 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row6_col0" class="data row6 col0" >cockpit_1x4</td>
#                         <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row6_col1" class="data row6 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row7_col0" class="data row7 col0" >generator_2x2</td>
#                         <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row7_col1" class="data row7 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row8_col0" class="data row8 col0" >intake_3x2</td>
#                         <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row8_col1" class="data row8 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row9_col0" class="data row9 col0" >pump_1x1</td>
#                         <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row9_col1" class="data row9 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row10_col0" class="data row10 col0" >tank_2x1</td>
#                         <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row10_col1" class="data row10 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row11_col0" class="data row11 col0" >tank_4x2</td>
#                         <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row11_col1" class="data row11 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row12_col0" class="data row12 col0" >turret_5x2</td>
#                         <td id="T_104ca4d8_3a9e_11ec_aa3b_acde48001122row12_col1" class="data row12 col1" >4</td>
#             </tr>
#     </tbody></table>
