# %% [markdown]
# # quick 'n dirty solver for sunshine heavy industries.
#
# game is good, [buy it now on steam](https://store.steampowered.com/app/1542810/Sunshine_Heavy_Industries/).
#
# coming in second place in the leaderboard is no fun. use this notebook to change that.
#
# ## notes
#
# currently only solves for basic threshold constraints, manuverability, fuel & heatsink adjacency, and total-area constraints
#
# todo: armor requirements, cloaking area constraints, energy area constraints and x-width/y-width constraints
#
#
# ## to use
#
# cost table extracted as of halloween patch (10/30/2021-ish or so). packed asar needs to be extracted and then the obfuscated node module run in order to generate the full `costs.json` via `yarn generate` in the root node project.
#
# run this notebook w/ the relevant constraints.
# requires everything in `requirements.txt`. Also needs GLPK binary as mixed-integer linear programming solver.

# %%
from json import loads
import numpy as np
import pandas as pd
from pyomo.environ import *

costs = None
with open("costs.json") as f:
    costs = list(loads(f.read()).items())

print(f"Parts in DB: {len(costs)}")
# Out:
# Parts in DB: 108

# %%
def prop_vector(prop_name, default=0):
    return np.array([data.get(prop_name, default) for _, data in costs])

names = [n for n, _ in costs]
hitboxes = [np.array(data.get('hitbox', np.ones([data.get('width'),data.get('height')]))) for _, data in costs]
area = np.array([np.count_nonzero(hb) for hb in hitboxes])

borders = np.array([[not x in ob for x in range(4)] for ob in prop_vector('mustBeUnobstructed', [])])

perimeter = \
    prop_vector('height') * borders[:,0] + \
    prop_vector('width') * borders[:, 1] + \
    prop_vector('height') * borders[:, 2] + \
    prop_vector('width') * borders[:, 3]

data = pd.DataFrame({
    'part': names,
    'mass': area,
    'thrust': area * prop_vector('thrust'),
    'cost': area * prop_vector('cost'),
    'energy': area * prop_vector('energy'),
    'energyPiece': (prop_vector('energy') > 0) * 1,
    'fuel': area * prop_vector('fuel'),
    'firepower': area * prop_vector('firepower'),
    'passenger': area * prop_vector('quarters'),
    'command': area * prop_vector('command'),
    'agility': area * prop_vector('agility'),
    'cargo': area * prop_vector('cargo'),
    'fuelAdjacency': prop_vector('pump') * perimeter - prop_vector('mustTouchFuelPump'),
    'fuelPiece': prop_vector('pump'),
    'sinkPiece': prop_vector('heatsink'),
    'sinkAdjacency': prop_vector('heatsink') * perimeter - prop_vector('heat'),
    'fuelPiece': prop_vector('pump'),
})

# pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

data.set_index('part', inplace=True)
data
# Out:
#                  mass  thrust   cost  energy  energyPiece  fuel  firepower  \
# part
# antenna_1x2         2     0.0  100.0     0.0            0     0          0
# antenna_1x4         4     0.0  400.0     0.0            0     0          0
# antenna_1x5         5     0.0  300.0     0.0            0     0          0
# bunk_1x1            1     0.0   20.0     0.0            0     0          0
# bunk_2x1            2     0.0   40.0     0.0            0     0          0
# ...               ...     ...    ...     ...          ...   ...        ...
# tank_pod_3x3        9     0.0  315.0     0.0            0     9          0
# tractorbeam_2x3     4     0.0  120.0    -8.0            0     0          0
# turbine_2x2         4     0.0  900.0    40.0            1     0          0
# turret_5x2         10     0.0  400.0   -10.0            0     0         10
# turret_6x3         18     0.0  810.0   -18.0            0     0         18
#
#                  passenger  command  agility  cargo  fuelAdjacency  fuelPiece  \
# part
# antenna_1x2              0        0        0      0              0          0
# antenna_1x4              0        0        0      0              0          0
# antenna_1x5              0        0        0      0              0          0
# bunk_1x1                 1        0        0      0              0          0
# bunk_2x1                 2        0        0      0              0          0
# ...                    ...      ...      ...    ...            ...        ...
# tank_pod_3x3             0        0        0      0             -1          0
# tractorbeam_2x3          0        0        0      0              0          0
# turbine_2x2              0        0        0      0              0          0
# turret_5x2               0        0        0      0              0          0
# turret_6x3               0        0        0      0              0          0
#
#                  sinkPiece  sinkAdjacency
# part
# antenna_1x2              0              0
# antenna_1x4              0              0
# antenna_1x5              0              0
# bunk_1x1                 0              0
# bunk_2x1                 0              0
# ...                    ...            ...
# tank_pod_3x3             0              0
# tractorbeam_2x3          0             -1
# turbine_2x2              1              8
# turret_5x2               0             -1
# turret_6x3               0             -1
#
# [108 rows x 15 columns]

# %%
# normal constraints
FUEL = 14
THRUST = 32
FIREPOWER = 0
PASSENGER = 20
COMMAND = 4
CARGO = 18
MANUVERABILITY = 0.38

# dimension constraints
AREA_COST = 10

# arrangement tweaks
# (start at 0, increase if config is physically impossible)
FUEL_PIECE = 2
SINK_PIECE = 2
ENERGY_PIECE = 0
FUEL_ADJACENCY = 1 # number of blocked fuel pump ports

model = ConcreteModel()
model.x = Var(names, domain=NonNegativeIntegers)
model.total_cost = Objective(
    expr = sum(data.loc[i].cost * model.x[i] + data.loc[i].mass * AREA_COST * model.x[i]  for i in names),
    sense = minimize
)

# thresholds
model.fuel = Constraint(
    expr = sum(data.loc[i].fuel * model.x[i] for i in names) >= FUEL
)
model.thrust = Constraint(
    expr = sum(data.loc[i].thrust * model.x[i] for i in names) >= THRUST
)
model.firepower = Constraint(
    expr = sum(data.loc[i].firepower * model.x[i] for i in names) >= FIREPOWER
)
model.passenger = Constraint(
    expr = sum(data.loc[i].passenger * model.x[i] for i in names) >= PASSENGER
)
model.command = Constraint(
    expr = sum(data.loc[i].command * model.x[i] for i in names) >= COMMAND
)
model.cargo = Constraint(
    expr = sum(data.loc[i].cargo * model.x[i] for i in names) >= CARGO
)
model.energy = Constraint(
    expr = sum(data.loc[i].energy * model.x[i] for i in names) >= 0
)

# adjacencies
model.fuelAdjacency = Constraint(
    expr = sum(data.loc[i].fuelAdjacency * model.x[i] for i in names) >= FUEL_ADJACENCY
)
model.sinkAdjacency = Constraint(
    expr = sum(data.loc[i].sinkAdjacency * model.x[i] for i in names) >= 0
)

# tweaks
model.fuelPiece = Constraint(
    expr = sum(data.loc[i].fuelPiece * model.x[i] for i in names) >= FUEL_PIECE
)

model.sinkPiece = Constraint(
    expr = sum(data.loc[i].sinkPiece * model.x[i] for i in names) >= SINK_PIECE
)

model.energy_piece = Constraint(
    expr = sum(data.loc[i].energyPiece * model.x[i] for i in names) >= ENERGY_PIECE
)


# agility / mass >= manuverability
model.agility = Constraint(
    expr = sum((data.loc[i].agility - MANUVERABILITY * data.loc[i].mass) * model.x[i] for i in names) >= 0
)

solver=SolverFactory('glpk', executable="/usr/local/bin/glpsol")
results = solver.solve(model)
print(results)
model.display()


res = []
for i in model.x:
    if(model.x[i].value > 0):
        res.append([str(model.x[i])[2:-1], int(model.x[i].value)])
        
df = pd.DataFrame(res, columns=['Part','Qty'])
df.style.hide_index()
# Out:
# Problem:
# - Name: unknown
#   Lower bound: 3865.0
#   Upper bound: 3865.0
#   Number of objectives: 1
#   Number of constraints: 14
#   Number of variables: 109
#   Number of nonzeros: 258
#   Sense: minimize
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 79
#       Number of created subproblems: 79
#   Error rc: 0
#   Time: 0.013914823532104492
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Model unknown
#
#   Variables:
#     x : Size=108, Index=x_index
#         Key                 : Lower : Value : Upper : Fixed : Stale : Domain
#                 antenna_1x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                 antenna_1x4 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                 antenna_1x5 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    bunk_1x1 :     0 :  16.0 :  None : False : False : NonNegativeIntegers
#                    bunk_2x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    bunk_4x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    bunk_4x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#              bunk_norad_4x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                     cab_2x2 :     0 :   1.0 :  None : False : False : NonNegativeIntegers
#                  cannon_2x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  cannon_2x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  cannon_4x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  cannon_5x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   cargo_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   cargo_2x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   cargo_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   cargo_5x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#               cargo_rad_3x2 :     0 :   3.0 :  None : False : False : NonNegativeIntegers
#                    claw_3x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   cloak_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   cloak_3x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                 cockpit_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                 cockpit_1x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                 cockpit_1x4 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                 cockpit_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                 cockpit_2x4 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    cone_1x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                     cpu_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    dish_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   drill_3x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  engine_3x1 :     0 :   1.0 :  None : False : False : NonNegativeIntegers
#                  engine_3x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  engine_4x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  engine_5x1 :     0 :   1.0 :  None : False : False : NonNegativeIntegers
#                  engine_6x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  engine_7x4 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#          engine_rainbow_4x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#             enginedirty_4x2 :     0 :   2.0 :  None : False : False : NonNegativeIntegers
#             enginegarbo_8x5 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#              enginegold_4x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#               engineion_4x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                     fin_1x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                     fin_2x2 :     0 :   1.0 :  None : False : False : NonNegativeIntegers
#                     fin_3x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                     fin_4x4 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#              fin_cannon_3x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   flier_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                 ftlcore_2x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#               generator_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#               generator_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                     gpu_3x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#              greenhouse_5x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#               heat_pipe_2x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#               heat_vent_1x1 :     0 :   2.0 :  None : False : False : NonNegativeIntegers
#                heatsink_1x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                heatsink_1x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    horn_2x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#              hull_round_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#              hull_round_4x4 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  intake_3x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                     lab_2x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  panel_10x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   panel_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   panel_2x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   panel_3x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   panel_4x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#           panel_concave_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#           panel_concave_4x4 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#           panel_corner2_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#            panel_corner_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#            panel_corner_2x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#            panel_corner_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#             panel_curve_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#               propeller_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    pump_1x1 :     0 :   2.0 :  None : False : False : NonNegativeIntegers
#                    pump_1x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                pumpcast_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   radar_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   radar_1x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   radar_2x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#         radar_longrange_2x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                     ram_2x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                 reactor_3x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                scaffold_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                scaffold_1x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#               scaffold_1x20 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                scaffold_1x4 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   scrap_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   scrap_1x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   scrap_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   scrap_2x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#             solar_panel_3x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                 speaker_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   stage_6x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#              stasis_pod_2x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    tank_1x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    tank_2x1 :     0 :   1.0 :  None : False : False : NonNegativeIntegers
#                    tank_2x2 :     0 :   1.0 :  None : False : False : NonNegativeIntegers
#                    tank_3x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                    tank_4x2 :     0 :   1.0 :  None : False : False : NonNegativeIntegers
#                    tank_6x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#           tank_cylinder_3x4 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#               tank_hull_4x1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                tank_pod_3x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#             tractorbeam_2x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                 turbine_2x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  turret_5x2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  turret_6x3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#
#   Objectives:
#     total_cost : Size=1, Index=None, Active=True
#         Key  : Active : Value
#         None :   True : 3865.0
#
#   Constraints:
#     fuel : Size=1
#         Key  : Lower : Body : Upper
#         None :  14.0 : 14.0 :  None
#     thrust : Size=1
#         Key  : Lower : Body : Upper
#         None :  32.0 : 32.0 :  None
#     firepower : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :  None
#     passenger : Size=1
#         Key  : Lower : Body : Upper
#         None :  20.0 : 20.0 :  None
#     command : Size=1
#         Key  : Lower : Body : Upper
#         None :   4.0 :  4.0 :  None
#     cargo : Size=1
#         Key  : Lower : Body : Upper
#         None :  18.0 : 18.0 :  None
#     energy : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :  None
#     fuelAdjacency : Size=1
#         Key  : Lower : Body : Upper
#         None :   1.0 :  1.0 :  None
#     sinkAdjacency : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  2.0 :  None
#     fuelPiece : Size=1
#         Key  : Lower : Body : Upper
#         None :   2.0 :  2.0 :  None
#     sinkPiece : Size=1
#         Key  : Lower : Body : Upper
#         None :   2.0 :  2.0 :  None
#     energy_piece : Size=1
#         Key  : Lower : Body : Upper
#         None :   0.0 :  0.0 :  None
#     agility : Size=1
#         Key  : Lower : Body              : Upper
#         None :   0.0 : 8.079999999999995 :  None
# <style  type="text/css" >
# </style><table id="T_f031cd4a_3acf_11ec_8245_acde48001122" ><thead>    <tr>        <th class="col_heading level0 col0" >Part</th>        <th class="col_heading level0 col1" >Qty</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row0_col0" class="data row0 col0" >bunk_1x1</td>
#                         <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row0_col1" class="data row0 col1" >16</td>
#             </tr>
#             <tr>
#                                 <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row1_col0" class="data row1 col0" >cab_2x2</td>
#                         <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row1_col1" class="data row1 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row2_col0" class="data row2 col0" >cargo_rad_3x2</td>
#                         <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row2_col1" class="data row2 col1" >3</td>
#             </tr>
#             <tr>
#                                 <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row3_col0" class="data row3 col0" >engine_3x1</td>
#                         <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row3_col1" class="data row3 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row4_col0" class="data row4 col0" >engine_5x1</td>
#                         <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row4_col1" class="data row4 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row5_col0" class="data row5 col0" >enginedirty_4x2</td>
#                         <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row5_col1" class="data row5 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row6_col0" class="data row6 col0" >fin_2x2</td>
#                         <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row6_col1" class="data row6 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row7_col0" class="data row7 col0" >heat_vent_1x1</td>
#                         <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row7_col1" class="data row7 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row8_col0" class="data row8 col0" >pump_1x1</td>
#                         <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row8_col1" class="data row8 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row9_col0" class="data row9 col0" >tank_2x1</td>
#                         <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row9_col1" class="data row9 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row10_col0" class="data row10 col0" >tank_2x2</td>
#                         <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row10_col1" class="data row10 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row11_col0" class="data row11 col0" >tank_4x2</td>
#                         <td id="T_f031cd4a_3acf_11ec_8245_acde48001122row11_col1" class="data row11 col1" >1</td>
#             </tr>
#     </tbody></table>
